# %% [markdown]
# Какова доля семей ,в которых минимальный возраст меньше 20 (семьи детьми)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yasserh/titanic-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 22.0k/22.0k [00:00<00:00, 933kB/s]
# Extracting files...
# Path to dataset files: C:\Users\zhcri\.cache\kagglehub\datasets\yasserh\titanic-dataset\versions\1

# %%
import pandas as pd

df=pd.read_csv('C:/Users/zhcri/.cache/kagglehub/datasets/yasserh/titanic-dataset/versions/1/Titanic-Dataset.csv')
df.head()
df['Surname'] = df['Name'].str.split(',').str[0]
min_age_by_family = df.groupby('Surname')['Age'].min()
share = (min_age_by_family < 20).mean()
share
# Out:
# np.float64(0.18590704647676162)

# %% [markdown]
# Какова доля выживших пассажиров из класса 3 ? А пассажиров из класса 1?

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Surname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
survival_rate_class1 = df[df['Pclass'] == 1]['Survived'].mean()
survival_rate_class3 = df[df['Pclass'] == 3]['Survived'].mean()

# %%
survival_rate_class1
# Out:
# np.float64(0.6296296296296297)

# %%
survival_rate_class3
# Out:
# np.float64(0.24236252545824846)
